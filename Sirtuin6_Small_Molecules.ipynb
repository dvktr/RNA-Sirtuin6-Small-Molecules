# %% [markdown]
# <a href="https://colab.research.google.com/github/dvktr/RNA-Sirtuin6-Small-Molecules/blob/main/Sirtuin6_Small_Molecules.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# Carregar o dataset
file_path = '/content/sample_data/SIRTUIN6.csv'
df = pd.read_csv(file_path)

# Exibir as primeiras linhas do dataset
df.head(), df.info(), df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   SC-5      100 non-null    float64
#  1   SP-6      100 non-null    float64
#  2   SHBd      100 non-null    float64
#  3   minHaaCH  100 non-null    float64
#  4   maxwHBa   100 non-null    float64
#  5   FMF       100 non-null    float64
#  6   Class     100 non-null    object
# dtypes: float64(6), object(1)
# memory usage: 5.6+ KB
# (       SC-5     SP-6      SHBd  minHaaCH  maxwHBa       FMF     Class
#  0  0.540936  7.64192  0.162171  0.445270  2.20557  0.467742  High_BFE
#  1  0.815332  6.59011  0.000000  0.497445  2.00314  0.415385  High_BFE
#  2  0.734399  6.85522  0.000000  0.507748  1.88590  0.400000  High_BFE
#  3  0.624557  7.00949  0.450300  0.483648  2.02757  0.500000  High_BFE
#  4  0.460290  4.92643  0.448998  0.482293  2.06438  0.536585  High_BFE,
#  None,
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Matriz de Correlação
correlation_matrix = df.corr()

# Exibir a matriz de correlação
print(correlation_matrix)


# Visualizar a matriz de correlação como um heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.show()
# Out:
#               SC-5      SP-6      SHBd  minHaaCH   maxwHBa       FMF
# SC-5      1.000000  0.662082 -0.101657  0.110145 -0.083664  0.181699
# SP-6      0.662082  1.000000 -0.113093  0.195699  0.089528  0.579867
# SHBd     -0.101657 -0.113093  1.000000  0.232591  0.049229  0.052574
# minHaaCH  0.110145  0.195699  0.232591  1.000000  0.460770  0.258250
# maxwHBa  -0.083664  0.089528  0.049229  0.460770  1.000000  0.189825
# FMF       0.181699  0.579867  0.052574  0.258250  0.189825  1.000000

# %%
for coluna in df:
    plt.figure()
    df[coluna].hist(bins=30, edgecolor='black')
    plt.title(f'Histograma de {coluna}')
    plt.xlabel(coluna)
    plt.ylabel('Frequência')
    plt.show()
